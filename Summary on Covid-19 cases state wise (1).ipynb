# %% [markdown]
# # Insights on covid-19 cases state wise

# %% [markdown]
# ***Important insights that can be drawn from this data***
#
# 1.Most affected state
#
# 2.Finding the red zones(Danger areas)
#
# 3.In which state lockdown should be kept and lifted
#
# ***Note:*** This data of COVID_19 cases is upto 10/08/2021

# %%
import numpy as np # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import matplotlib.pyplot as plt # for visualization

# %%
data=pd.read_csv('state_wise.csv') #for reading the data

# %%
data
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 0                                      Total   32031440   31208694  429156
# 1                Andaman and Nicobar Islands       7546       7412     129
# 2                             Andhra Pradesh    1985182    1952736   13564
# 3                          Arunachal Pradesh      50372      47520     246
# 4                                      Assam     575220     558720    5404
# 5                                      Bihar     725235     715303    9646
# 6                                 Chandigarh      61992      61150     811
# 7                               Chhattisgarh    1003244     988004   13540
# 8   Dadra and Nagar Haveli and Daman and Diu      10657      10615       4
# 9                                      Delhi    1436852    1411280   25068
# 10                                       Goa     172085     167978    3164
# ...

# %%
data.head() #shows top 5 rows from top
# Out:
#                          State  Confirmed  Recovered  Deaths  Active  \
# 0                        Total   32031440   31208694  429156  380959
# 1  Andaman and Nicobar Islands       7546       7412     129       5
# 2               Andhra Pradesh    1985182    1952736   13564   18882
# 3            Arunachal Pradesh      50372      47520     246    2606
# 4                        Assam     575220     558720    5404    9749
#
#      Last_Updated_Time  Migrated_Other State_code  Delta_Confirmed  \
# 0  10/08/2021 19:57:11           12631         TT            34416
# 1  09/08/2021 20:12:16               0         AN                0
# 2  10/08/2021 19:57:13               0         AP             1461
# 3  10/08/2021 00:59:17               0         AR                0
# 4  10/08/2021 00:59:19            1347         AS                0
#
#    Delta_Recovered  Delta_Deaths  \
# 0            35307           441
# 1                0             0
# 2             2113            15
# ...

# %%
data.head(25)  #shows top 25 rows from top
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 1                Andaman and Nicobar Islands       7546       7412     129
# 2                             Andhra Pradesh    1985182    1952736   13564
# 3                          Arunachal Pradesh      50372      47520     246
# 4                                      Assam     575220     558720    5404
# 5                                      Bihar     725235     715303    9646
# 6                                 Chandigarh      61992      61150     811
# 7                               Chhattisgarh    1003244     988004   13540
# 8   Dadra and Nagar Haveli and Daman and Diu      10657      10615       4
# 9                                      Delhi    1436852    1411280   25068
# 10                                       Goa     172085     167978    3164
# 11                                   Gujarat     825064     814778   10077
# ...

# %%
data.tail()  #shows top 5 rows from bottom
# Out:
#             State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 33      Telangana     649859     637789    3828    8242  09/08/2021 20:12:26
# 34        Tripura      80413      77538     768    2044  10/08/2021 19:57:54
# 35  Uttar Pradesh    1708793    1685449   22774     570  10/08/2021 02:22:23
# 36    Uttarakhand     342462     328610    7368     444  10/08/2021 19:57:56
# 37    West Bengal    1534999    1506532   18252   10215  10/08/2021 19:57:58
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 33               0         TG                0                0             0
# 34              63         TR              205              308             1
# 35               0         UP                0                0             0
# 36            6040         UT               39               41             0
# 37               0         WB              639              724            12
#
# ...

# %%
data.columns  #shows names of features
# Out:
# Index(['State', 'Confirmed', 'Recovered', 'Deaths', 'Active',
#        'Last_Updated_Time', 'Migrated_Other', 'State_code', 'Delta_Confirmed',
#        'Delta_Recovered', 'Delta_Deaths', 'State_Notes'],
#       dtype='object')

# %%
data.dtypes #shows datatypes of features
# Out:
# State                object
# Confirmed             int64
# Recovered             int64
# Deaths                int64
# Active                int64
# Last_Updated_Time    object
# Migrated_Other        int64
# State_code           object
# Delta_Confirmed       int64
# Delta_Recovered       int64
# Delta_Deaths          int64
# State_Notes          object
# dtype: object

# %%
data.info() #shows basic information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 1 to 37
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              37 non-null     object
#  1   Confirmed          37 non-null     int64
#  2   Recovered          37 non-null     int64
#  3   Deaths             37 non-null     int64
#  4   Active             37 non-null     int64
#  5   Last_Updated_Time  37 non-null     object
#  6   Migrated_Other     37 non-null     int64
#  7   State_code         37 non-null     object
#  8   Delta_Confirmed    37 non-null     int64
#  9   Delta_Recovered    37 non-null     int64
#  10  Delta_Deaths       37 non-null     int64
#  11  State_Notes        14 non-null     object
# dtypes: int64(8), object(4)
# memory usage: 4.8+ KB

# %%
data.describe()
# Out:
#           Confirmed     Recovered         Deaths         Active  \
# count  3.800000e+01  3.800000e+01      38.000000      38.000000
# mean   1.685865e+06  1.642563e+06   22587.157895   20050.473684
# std    5.211015e+06  5.075309e+06   71370.875143   66920.344879
# min    0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    6.393625e+04  6.190175e+04     778.750000     233.250000
# 50%    4.613130e+05  4.503970e+05    5267.000000    1347.500000
# 75%    9.996822e+05  9.841805e+05   13558.000000    9312.250000
# max    3.203144e+07  3.120869e+07  429156.000000  380959.000000
#
#        Migrated_Other  Delta_Confirmed  Delta_Recovered  Delta_Deaths
# count       38.000000        38.000000        38.000000     38.000000
# mean       664.789474      1811.368421      1858.263158     23.210526
# std       2289.346881      6460.683222      6427.995332     77.372793
# min          0.000000         0.000000         0.000000      0.000000
# ...

# %%
data.describe(include='all')
# Out:
#         State     Confirmed     Recovered         Deaths         Active  \
# count      38  3.800000e+01  3.800000e+01      38.000000      38.000000
# unique     38           NaN           NaN            NaN            NaN
# top     Total           NaN           NaN            NaN            NaN
# freq        1           NaN           NaN            NaN            NaN
# mean      NaN  1.685865e+06  1.642563e+06   22587.157895   20050.473684
# std       NaN  5.211015e+06  5.075309e+06   71370.875143   66920.344879
# min       NaN  0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%       NaN  6.393625e+04  6.190175e+04     778.750000     233.250000
# 50%       NaN  4.613130e+05  4.503970e+05    5267.000000    1347.500000
# 75%       NaN  9.996822e+05  9.841805e+05   13558.000000    9312.250000
# max       NaN  3.203144e+07  3.120869e+07  429156.000000  380959.000000
#
#           Last_Updated_Time  Migrated_Other State_code  Delta_Confirmed  \
# ...

# %%
maxvalues=data.max()

# %%
maxvalues
# Out:
# State                        West Bengal
# Confirmed                       32031440
# Recovered                       31208694
# Deaths                            429156
# Active                            380959
# Last_Updated_Time    19/07/2020 09:40:01
# Migrated_Other                     12631
# State_code                            WB
# Delta_Confirmed                    34416
# Delta_Recovered                    35307
# Delta_Deaths                         441
# dtype: object

# %%
maxvalues=data.max(axis=1)

# %%
maxvalues
# Out:
# 0     32031440
# 1         7546
# 2      1985182
# 3        50372
# 4       575220
# 5       725235
# 6        61992
# 7      1003244
# 8        10657
# 9      1436852
# 10      172085
# 11      825064
# 12      770114
# 13      208616
# 14      322771
# 15      347406
# 16     2921049
# 17     3586693
# 18       20400
# 19       10263
# 20      791980
# 21     6363442
# 22      105424
# 23       69769
# 24       45457
# 25       28709
# 26      988997
# 27      121766
# 28      599514
# 29      953840
# 30       28018
# 31           0
# 32     2577237
# 33      649859
# 34       80413
# 35     1708793
# 36      342462
# 37     1534999
# dtype: int64

# %%
data.loc[data['Confirmed']==953840]
# Out:
#         State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 29  Rajasthan     953840     944670    8954     216  09/08/2021 19:37:18
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 29               0         RJ                0                0             0
#
#    State_Notes
# 29         NaN

# %%
data.iloc[29]
# Out:
# State                          Rajasthan
# Confirmed                         953840
# Recovered                         944670
# Deaths                              8954
# Active                               216
# Last_Updated_Time    09/08/2021 19:37:18
# Migrated_Other                         0
# State_code                            RJ
# Delta_Confirmed                        0
# Delta_Recovered                        0
# Delta_Deaths                           0
# State_Notes                          NaN
# Name: 29, dtype: object

# %%
data.drop([0], inplace = True)

# %%
data
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 1                Andaman and Nicobar Islands       7546       7412     129
# 2                             Andhra Pradesh    1985182    1952736   13564
# 3                          Arunachal Pradesh      50372      47520     246
# 4                                      Assam     575220     558720    5404
# 5                                      Bihar     725235     715303    9646
# 6                                 Chandigarh      61992      61150     811
# 7                               Chhattisgarh    1003244     988004   13540
# 8   Dadra and Nagar Haveli and Daman and Diu      10657      10615       4
# 9                                      Delhi    1436852    1411280   25068
# 10                                       Goa     172085     167978    3164
# 11                                   Gujarat     825064     814778   10077
# ...

# %%
data.max()
# Out:
# State                        West Bengal
# Confirmed                        6363442
# Recovered                        6159676
# Deaths                            134201
# Active                            171985
# Last_Updated_Time    19/07/2020 09:40:01
# Migrated_Other                      6040
# State_code                            WB
# Delta_Confirmed                    21119
# Delta_Recovered                    18493
# Delta_Deaths                         152
# dtype: object

# %%
data.loc[data['Confirmed']==6363442]
# Out:
#           State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 21  Maharashtra    6363442    6159676  134201   66123  10/08/2021 19:57:35
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 21            3442         MH             5609             7720           137
#
#                                           State_Notes
# 21  [Dec 16]:10,218 duplicate cases & other state ...

# %%
data.loc[data['Recovered']==6159676]
# Out:
#           State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 21  Maharashtra    6363442    6159676  134201   66123  10/08/2021 19:57:35
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 21            3442         MH             5609             7720           137
#
#                                           State_Notes
# 21  [Dec 16]:10,218 duplicate cases & other state ...

# %%
data.loc[data['Deaths']==134201]
# Out:
#           State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 21  Maharashtra    6363442    6159676  134201   66123  10/08/2021 19:57:35
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 21            3442         MH             5609             7720           137
#
#                                           State_Notes
# 21  [Dec 16]:10,218 duplicate cases & other state ...

# %%
data.loc[data['Active']==171985]
# Out:
#      State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 17  Kerala    3586693    3396184   18004  171985  10/08/2021 19:57:29
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 17             520         KL            21119            18493           152
#
#    State_Notes
# 17         NaN

# %%
data.loc[data['Delta_Confirmed']==21119]
# Out:
#      State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 17  Kerala    3586693    3396184   18004  171985  10/08/2021 19:57:29
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 17             520         KL            21119            18493           152
#
#    State_Notes
# 17         NaN

# %%
data.loc[data['Delta_Recovered']==18493]
# Out:
#      State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 17  Kerala    3586693    3396184   18004  171985  10/08/2021 19:57:29
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 17             520         KL            21119            18493           152
#
#    State_Notes
# 17         NaN

# %%
data.loc[data['Delta_Deaths']==152]
# Out:
#      State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 17  Kerala    3586693    3396184   18004  171985  10/08/2021 19:57:29
#
#     Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 17             520         KL            21119            18493           152
#
#    State_Notes
# 17         NaN

# %%
data.min()
# Out:
# State                Andaman and Nicobar Islands
# Confirmed                                      0
# Recovered                                      0
# Deaths                                         0
# Active                                         0
# Last_Updated_Time            09/08/2021 19:37:18
# Migrated_Other                                 0
# State_code                                    AN
# Delta_Confirmed                                0
# Delta_Recovered                                0
# Delta_Deaths                                   0
# dtype: object

# %%
data.plot(kind = 'bar',
        x = 'State_code',
        y = 'Confirmed',
        color = 'red')
  
# set the title
plt.title('BarPlot')
  
# show the plot
plt.show()

# %%
data.plot(kind = 'bar',
        x = 'State_code',
        y = 'Recovered',
        color = 'green')
  
plt.title('BarPlot')
plt.show()

# %%
death_rateof_MH= [(134201/6363442)*100]

# %%
death_rateof_MH
# Out:
# [2.1089372701126217]

# %% [markdown]
# **From my analysis I found these things**
#
# 1.Maharastra is the most affected state with the death rate of 2.108%.
#
# 2.Delta variant is rapidly increasing in Kerala and Maharastra.
#
# **Suggestions**
#
# 1.Lockdown must be imposed in **Maharastra** if the state economic condition is good as delta variant is increasing in the state.
#
# 2.Lockdown with some exceptions must be imposed in **KERALA** as it is state with most Delta variant cases till date.
#
# 3.In the states like Karnataka,AP,DL,TN,UP,WB,TS,OR partial lockdown must be imposed for some days.
#
# 4.And in the remaining states lockdown can be lifted with some restrictions like MASK MUST and so on.

# %% [markdown]
# #                                            THANK YOU
